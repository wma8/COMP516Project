# %%
import collections
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn.pipeline import Pipeline

# %% [markdown]
# # Read and Visualize the Data

# %%
# read in data
data = pd.read_csv('NewYork.csv')
# Describe the data
data.head()
# Out:
#          id  host_response_time host_response_rate host_is_superhost  \
# 0  18461891                 NaN                NaN                 f
# 1  20702398      within an hour               100%                 f
# 2   6627449      within an hour               100%                 f
# 3  19949243  within a few hours               100%                 f
# 4   1886820                 NaN                NaN                 f
#
#   host_has_profile_pic neighbourhood_cleansed   latitude  longitude  \
# 0                    t       Ditmars Steinway  40.774142 -73.916246
# 1                    t            City Island  40.849191 -73.786509
# 2                    t            City Island  40.849775 -73.786609
# 3                    t            City Island  40.848838 -73.782276
# 4                    t            City Island  40.841144 -73.783052
#
#   is_location_exact property_type  ... maximum_nights  calendar_updated  \
# 0                 t     Apartment  ...              6      5 months ago
# 1                 f         House  ...             21       2 weeks ago
# 2                 t     Apartment  ...             21       2 weeks ago
# 3                 f          Boat  ...           1125        6 days ago
# 4                 t         House  ...             90     16 months ago
#
#    availability_30  number_of_reviews  review_scores_rating instant_bookable  \
# 0                0                  0                   NaN                f
# 1               19                  2                 100.0                f
# 2               28                 21                  95.0                f
# 3               30                  0                   NaN                t
# 4               30                  0                   NaN                f
#
#   is_business_travel_ready  cancellation_policy  \
# 0                        f               strict
# 1                        f             moderate
# 2                        f               strict
# 3                        f               strict
# 4                        f               strict
#
#    require_guest_profile_picture  reviews_per_month
# 0                              f                NaN
# 1                              f               2.00
# 2                              f               0.77
# 3                              f                NaN
# 4                              f                NaN
#
# [5 rows x 31 columns]

# %%
# pie
tmp  = data['review_scores_rating']
not_nan = tmp[tmp>0]
labels = 'terrible','fine','good','excellent'
terrible = len(tmp[tmp<=80])  # rate<=80
fine = len(tmp[tmp<=90])-terrible # 80 < rate <= 90
good = len(tmp[tmp<100]) - terrible - fine # 95 < rate < 100
excellent = len(tmp[tmp==100]) # rate = 100
sizes = [terrible, fine, good, excellent]
cmap = plt.get_cmap("tab20c")
colors = cmap(np.array([2, 1,6,10]))
fig1, ax1 = plt.subplots()
ax1.pie(sizes,  labels=labels, autopct = '%1.1f%%',shadow=False, startangle = 90,colors = colors)
ax1.axis('equal')
# Out:
# (-1.1019296620684242,
#  1.1089713385687547,
#  -1.1215025656294224,
#  1.1010239316966393)

# %%
regions = collections.Counter(data['neighbourhood_cleansed'])
sort_r = sorted(regions.items(), key = lambda x: x[1],reverse = True)[:10]
x_plt = []
y_plt = []
for i in range(len(sort_r)):
    price = data['price']
    regs = data['neighbourhood_cleansed']
    idxs = [regs==sort_r[i]]
    s= list(price[regs == sort_r[i][0]])
    x_plt += s
    y_plt += [sort_r[i][0]]*len(s)

print(len(x_plt),len(y_plt))
plt.plot(x_plt,y_plt,".")
# Out:
# 21837 21837

# %%
beds = data['room_type']
price = data['price']
plt.plot(price,beds,".")

# %% [markdown]
# # Data cleansing

# %%
data = data.drop(['id','neighbourhood_cleansed','host_has_profile_pic', 'latitude', 'longitude', 'square_feet', 'guests_included',
          'maximum_nights', 'calendar_updated', 'require_guest_profile_picture', 'is_business_travel_ready',
          'reviews_per_month', 'review_scores_rating'], axis = 1)

# %%
data
# Out:
#        host_response_time host_response_rate host_is_superhost  \
# 0                     NaN                NaN                 f
# 1          within an hour               100%                 f
# 2          within an hour               100%                 f
# 3      within a few hours               100%                 f
# 4                     NaN                NaN                 f
# 5          within an hour               100%                 t
# 6          within an hour               100%                 f
# 7          within an hour               100%                 t
# 8      within a few hours               100%                 f
# 9                     NaN                NaN                 f
# 10         within an hour               100%                 t
# 11     a few days or more                33%                 f
# 12         within an hour               100%                 f
# 13         within an hour               100%                 t
# 14         within an hour               100%                 f
# 15         within an hour               100%                 f
# 16         within an hour               100%                 f
# 17                    NaN                NaN                 f
# 18         within an hour               100%                 f
# 19                    NaN                NaN                 f
# 20         within an hour               100%                 f
# 21     within a few hours               100%                 f
# 22     within a few hours               100%                 f
# 23           within a day               100%                 f
# 24           within a day                75%                 f
# 25         within an hour               100%                 f
# 26         within an hour               100%                 f
# 27         within an hour               100%                 f
# 28         within an hour               100%                 f
# 29         within an hour               100%                 f
# ...                   ...                ...               ...
# 44287        within a day                60%                 f
# 44288  a few days or more                25%                 f
# 44289      within an hour                83%                 f
# 44290                 NaN                NaN                 f
# 44291                 NaN                NaN                 f
# 44292                 NaN                NaN                 f
# 44293                 NaN                NaN                 f
# 44294      within an hour               100%                 f
# 44295      within an hour               100%                 f
# 44296      within an hour               100%                 f
# 44297      within an hour               100%                 f
# 44298  a few days or more                 0%                 f
# 44299  within a few hours               100%                 f
# 44300                 NaN                NaN                 f
# 44301      within an hour               100%                 f
# 44302  within a few hours               100%                 f
# 44303      within an hour               100%                 f
# 44304      within an hour               100%                 f
# 44305      within an hour               100%                 f
# 44306                 NaN                NaN                 f
# 44307  within a few hours               100%                 f
# 44308  within a few hours               100%                 f
# 44309      within an hour               100%                 f
# 44310                 NaN                NaN                 f
# 44311  within a few hours               100%                 f
# 44312      within an hour                90%                 f
# 44313  within a few hours               100%                 f
# 44314      within an hour               100%                 f
# 44315      within an hour               100%                 f
# 44316                 NaN                NaN                 f
#
#       is_location_exact property_type        room_type  accommodates  \
# 0                     t     Apartment  Entire home/apt             2
# 1                     f         House     Private room             2
# 2                     t     Apartment  Entire home/apt             3
# 3                     f          Boat  Entire home/apt             4
# 4                     t         House  Entire home/apt             4
# 5                     t         House     Private room             4
# 6                     t     Apartment  Entire home/apt             7
# 7                     t         House     Private room             2
# 8                     f          Boat  Entire home/apt             4
# 9                     t     Apartment     Private room             4
# 10                    f         House  Entire home/apt             2
# 11                    t     Apartment  Entire home/apt             2
# 12                    t         House  Entire home/apt             4
# 13                    t         House  Entire home/apt             4
# 14                    t         House     Private room             2
# 15                    t         House     Private room             2
# 16                    t     Apartment     Private room             3
# 17                    t         House     Private room             2
# 18                    t         House     Private room             2
# 19                    f     Apartment     Private room             2
# 20                    t         House  Entire home/apt             4
# 21                    f     Apartment     Private room             2
# 22                    t     Apartment     Private room             1
# 23                    t     Apartment      Shared room             1
# 24                    f     Apartment  Entire home/apt             2
# 25                    f         House     Private room             4
# 26                    t     Apartment  Entire home/apt             8
# 27                    t         House  Entire home/apt             7
# 28                    t     Apartment  Entire home/apt             6
# 29                    f     Apartment     Private room             3
# ...                 ...           ...              ...           ...
# 44287                 t     Apartment  Entire home/apt             2
# 44288                 t     Apartment     Private room             1
# 44289                 t     Apartment     Private room             2
# 44290                 t     Apartment     Private room             2
# 44291                 t     Apartment     Private room             1
# 44292                 t     Apartment  Entire home/apt             2
# 44293                 f     Apartment     Private room             2
# 44294                 t     Apartment     Private room             1
# 44295                 t     Apartment     Private room             2
# 44296                 t     Apartment  Entire home/apt             5
# 44297                 t     Apartment  Entire home/apt             3
# 44298                 t     Apartment     Private room             3
# 44299                 t     Apartment  Entire home/apt             4
# 44300                 t     Apartment     Private room             4
# 44301                 t         House  Entire home/apt             6
# 44302                 f     Apartment  Entire home/apt             3
# 44303                 t     Apartment     Private room             2
# 44304                 t         House  Entire home/apt            10
# 44305                 f         Other     Private room             2
# 44306                 t         House     Private room             2
# 44307                 t     Apartment  Entire home/apt             1
# 44308                 f     Apartment     Private room             2
# 44309                 t         House     Private room             1
# 44310                 t     Apartment  Entire home/apt             3
# 44311                 t         House     Private room             2
# 44312                 f     Apartment     Private room             1
# 44313                 t     Apartment  Entire home/apt             6
# 44314                 f     Apartment  Entire home/apt             4
# 44315                 f     Apartment  Entire home/apt             2
# 44316                 f     Apartment  Entire home/apt             4
#
#        bathrooms  bedrooms  beds  bed_type  \
# 0            1.0       0.0   1.0  Real Bed
# 1            1.0       1.0   1.0  Real Bed
# 2            1.0       1.0   1.0  Real Bed
# 3            1.0       1.0   3.0  Real Bed
# 4            3.0       3.0   3.0  Real Bed
# 5            1.0       1.0   1.0  Real Bed
# 6            1.0       2.0   5.0  Real Bed
# 7            1.0       1.0   1.0  Real Bed
# 8            1.5       2.0   2.0  Real Bed
# 9            1.0       1.0   1.0  Real Bed
# 10           1.0       0.0   1.0  Real Bed
# 11           1.0       1.0   2.0  Real Bed
# 12           2.0       3.0   3.0  Real Bed
# 13           1.0       1.0   2.0  Real Bed
# 14           1.5       1.0   1.0  Real Bed
# 15           1.5       1.0   1.0  Real Bed
# 16           1.0       1.0   2.0  Real Bed
# 17           1.0       1.0   1.0  Real Bed
# 18           1.5       1.0   1.0  Real Bed
# 19           1.0       1.0   1.0  Real Bed
# 20           1.0       1.0   1.0  Real Bed
# 21           1.0       1.0   2.0  Real Bed
# 22           1.0       1.0   1.0  Real Bed
# 23           1.0       1.0   1.0  Real Bed
# 24           1.0       1.0   1.0  Real Bed
# 25           1.0       1.0   1.0  Real Bed
# 26           1.0       1.0   3.0  Real Bed
# 27           1.0       1.0   2.0  Real Bed
# 28           1.0       1.0   4.0  Real Bed
# 29           1.0       1.0   2.0  Real Bed
# ...          ...       ...   ...       ...
# 44287        2.0       2.0   2.0  Real Bed
# 44288        1.0       1.0   1.0  Real Bed
# 44289        1.0       1.0   1.0  Real Bed
# 44290        1.0       1.0   1.0  Real Bed
# 44291        1.0       1.0   1.0  Real Bed
# 44292        1.0       2.0   1.0  Real Bed
# 44293        1.5       1.0   2.0  Real Bed
# 44294        1.0       0.0   1.0  Real Bed
# 44295        1.0       1.0   1.0  Real Bed
# 44296        1.0       1.0   2.0  Real Bed
# 44297        1.0       1.0   2.0  Real Bed
# 44298        1.5       3.0   3.0  Real Bed
# 44299        1.0       3.0   4.0  Real Bed
# 44300        1.0       1.0   4.0  Real Bed
# 44301        2.5       4.0   5.0  Real Bed
# 44302        1.0       2.0   2.0  Real Bed
# 44303        1.0       2.0   1.0  Real Bed
# 44304        4.0       5.0   6.0  Real Bed
# 44305        1.0       1.0   1.0  Real Bed
# 44306        1.0       1.0   1.0  Real Bed
# 44307        1.0       1.0   1.0  Real Bed
# 44308        1.0       1.0   1.0  Real Bed
# 44309        1.5       1.0   1.0  Real Bed
# 44310        1.0       1.0   1.0  Real Bed
# 44311        1.0       1.0   1.0  Real Bed
# 44312        1.0       1.0   1.0  Real Bed
# 44313        1.0       3.0   5.0  Real Bed
# 44314        1.0       1.0   1.0  Real Bed
# 44315        1.0       0.0   1.0  Real Bed
# 44316        1.0       0.0   2.0  Real Bed
#
#                                                amenities  price  \
# 0      {TV,"Wireless Internet","Air conditioning",Kit...    110
# 1      {"Wireless Internet","Air conditioning",Kitche...     50
# 2      {TV,Internet,"Wireless Internet","Air conditio...    125
# 3                                                     {}    100
# 4      {TV,"Cable TV",Internet,"Wireless Internet","A...    300
# 5      {Internet,"Wireless Internet","Air conditionin...     69
# 6      {TV,"Air conditioning",Kitchen,"Free parking o...    150
# 7      {"Cable TV","Wireless Internet","Air condition...    101
# 8      {TV,"Wireless Internet","Air conditioning",Kit...    100
# 9      {TV,Internet,"Wireless Internet","Air conditio...    200
# 10     {TV,"Wireless Internet","Air conditioning",Kit...    125
# 11     {TV,"Cable TV",Internet,"Wireless Internet","A...    115
# 12     {"Wireless Internet","Air conditioning",Kitche...     62
# 13     {TV,"Cable TV",Internet,"Wireless Internet","A...     85
# 14     {Internet,"Wireless Internet","Air conditionin...     44
# 15     {TV,"Cable TV",Internet,"Wireless Internet","A...     47
# 16     {TV,Internet,"Wireless Internet","Air conditio...     39
# 17     {TV,"Wireless Internet","Air conditioning",Kit...     49
# 18     {TV,"Cable TV",Internet,"Wireless Internet","A...     85
# 19     {TV,"Wireless Internet","Air conditioning",Kit...     50
# 20     {TV,"Cable TV",Internet,"Wireless Internet","A...    105
# 21     {Internet,"Wireless Internet",Kitchen,"Smoking...     45
# 22     {TV,Internet,"Wireless Internet","Air conditio...     70
# 23     {TV,"Wireless Internet","Air conditioning",Kit...     65
# 24     {TV,Internet,"Wireless Internet",Kitchen,Heati...     90
# 25     {TV,"Cable TV","Wireless Internet","Air condit...     63
# 26     {TV,Internet,"Wireless Internet","Air conditio...    125
# 27     {TV,Internet,"Wireless Internet","Air conditio...    110
# 28     {TV,Internet,"Air conditioning","Wheelchair ac...    200
# 29     {TV,"Cable TV",Internet,"Wireless Internet","A...     38
# ...                                                  ...    ...
# 44287  {TV,Internet,"Wireless Internet","Air conditio...    300
# 44288  {"Cable TV",Internet,"Wireless Internet","Air ...     69
# 44289  {TV,Internet,"Wireless Internet","Air conditio...     60
# 44290  {"Wireless Internet",Kitchen,"Smoke detector",...     74
# 44291  {Internet,"Wireless Internet",Kitchen,Heating,...     60
# 44292  {Internet,"Wireless Internet","Air conditionin...    125
# 44293  {Internet,"Wireless Internet","Air conditionin...    100
# 44294  {"Wireless Internet","Smoke detector",Essentia...     60
# 44295  {TV,"Wireless Internet","Air conditioning",Kit...     45
# 44296  {TV,"Cable TV","Wireless Internet","Air condit...    135
# 44297  {TV,"Wireless Internet","Air conditioning",Kit...    136
# 44298  {"Wireless Internet",Kitchen,Breakfast,"Family...     80
# 44299  {Internet,"Wireless Internet","Air conditionin...    175
# 44300  {TV,"Wireless Internet","Air conditioning",Kit...     75
# 44301  {TV,"Wireless Internet","Air conditioning",Kit...    300
# 44302  {TV,"Wireless Internet","Air conditioning",Kit...    150
# 44303  {TV,"Cable TV",Internet,"Wireless Internet","A...     55
# 44304  {TV,"Wireless Internet","Air conditioning",Poo...    800
# 44305  {TV,"Cable TV","Wireless Internet","Air condit...    125
# 44306  {"Wireless Internet","Air conditioning",Kitche...     50
# 44307  {"Wireless Internet",Kitchen,Heating,"Family/k...    100
# 44308  {"Wireless Internet","Air conditioning",Kitche...     85
# 44309  {TV,Internet,"Wireless Internet",Kitchen,Heati...     45
# 44310  {TV,"Wireless Internet","Air conditioning",Poo...    300
# 44311  {"Wireless Internet",Kitchen,"Free parking on ...     48
# 44312  {"Wireless Internet","Air conditioning",Kitche...     90
# 44313  {"Wireless Internet","Air conditioning",Kitche...    199
# 44314  {"Wheelchair accessible",Kitchen,"Free parking...     91
# 44315  {TV,"Cable TV","Wireless Internet","Air condit...     75
# 44316  {TV,"Wireless Internet","Air conditioning",Kit...    148
#
#        minimum_nights  availability_30  number_of_reviews instant_bookable  \
# 0                   6                0                  0                f
# 1                   1               19                  2                f
# 2                   3               28                 21                f
# 3                   3               30                  0                t
# 4                   7               30                  0                f
# 5                   3                0                 94                t
# 6                   2               24                  3                f
# 7                   1               29                 31                f
# 8                   1               29                  0                t
# 9                   7               30                  0                t
# 10                  2               18                 60                f
# 11                  3                0                 49                t
# 12                  2               19                  9                f
# 13                  1               12                110                t
# 14                  2               14                 72                t
# 15                  2               17                 35                t
# 16                  2               19                131                f
# 17                  3                0                  1                t
# 18                  5                6                 33                f
# 19                  1                0                  5                f
# 20                  3               16                 27                f
# 21                  2               25                  9                f
# 22                  7               29                  5                f
# 23                  3               30                  0                f
# 24                  3               30                  1                f
# 25                  2               20                 23                f
# 26                  2               10                224                t
# 27                  3               20                 22                f
# 28                  1               16                 38                f
# 29                  2                8                 93                t
# ...               ...              ...                ...              ...
# 44287              14               29                  2                f
# 44288               5                0                 36                t
# 44289               5                0                  6                f
# 44290               1                0                  0                t
# 44291               7                0                  0                f
# 44292               2                0                 15                f
# 44293               3               18                 21                f
# 44294               7                0                  0                f
# 44295               2               19                  3                t
# 44296               2                4                  0                t
# 44297               7               22                  0                f
# 44298               2               30                  0                f
# 44299               7                6                  0                f
# 44300               2               28                  0                t
# 44301               2               21                  2                t
# 44302               1                0                  0                t
# 44303               1                0                  0                t
# 44304               6               25                  0                f
# 44305               1                0                  3                t
# 44306               1               25                  0                f
# 44307               7                1                  2                t
# 44308               1               10                  0                f
# 44309               1               19                  0                t
# 44310               2                0                  0                f
# 44311               2               26                  7                f
# 44312               1               30                  1                t
# 44313               3                4                  0                t
# 44314               1                1                  6                f
# 44315               2                7                  0                f
# 44316               2               17                  0                f
#
#       cancellation_policy
# 0                  strict
# 1                moderate
# 2                  strict
# 3                  strict
# 4                  strict
# 5                moderate
# 6                flexible
# 7                moderate
# 8                  strict
# 9                flexible
# 10               moderate
# 11                 strict
# 12               moderate
# 13               flexible
# 14                 strict
# 15               moderate
# 16                 strict
# 17               flexible
# 18                 strict
# 19                 strict
# 20                 strict
# 21                 strict
# 22                 strict
# 23               flexible
# 24               flexible
# 25               moderate
# 26                 strict
# 27                 strict
# 28                 strict
# 29                 strict
# ...                   ...
# 44287              strict
# 44288            flexible
# 44289            moderate
# 44290            flexible
# 44291            flexible
# 44292              strict
# 44293              strict
# 44294            flexible
# 44295              strict
# 44296            flexible
# 44297              strict
# 44298            flexible
# 44299              strict
# 44300            flexible
# 44301            moderate
# 44302            flexible
# 44303            flexible
# 44304              strict
# 44305            flexible
# 44306            flexible
# 44307            flexible
# 44308            flexible
# 44309            flexible
# 44310              strict
# 44311            flexible
# 44312            flexible
# 44313              strict
# 44314            moderate
# 44315              strict
# 44316            flexible
#
# [44317 rows x 18 columns]

# %%
for key in data:
    data = data[pd.notnull(data[key])]

# %%
data.host_response_time.unique()
# Out:
# array(['within an hour', 'within a few hours', 'a few days or more',
#        'within a day'], dtype=object)

# %%
data['host_response_time'] = data['host_response_time'].map({'within an hour': 1, 'within a few hours': 2, 
                                                            'a few days or more': 4, 'within a day': 3})

# %%
data.dtypes
# Out:
# host_response_time       int64
# host_response_rate      object
# host_is_superhost       object
# is_location_exact       object
# property_type           object
# room_type               object
# accommodates             int64
# bathrooms              float64
# bedrooms               float64
# beds                   float64
# bed_type                object
# amenities               object
# price                    int64
# minimum_nights           int64
# availability_30          int64
# number_of_reviews        int64
# instant_bookable        object
# cancellation_policy     object
# dtype: object

# %%
def p2f(x):
    return float(x.strip('%'))/100

# %%
data['host_response_rate'] = data['host_response_rate'].apply(p2f)

# %%
data['host_is_superhost'] = data['host_is_superhost'].map({'f': 0, 't': 1})

# %%
data['is_location_exact'] = data['is_location_exact'].map({'f': 0, 't': 1})

# %%
data.property_type.unique()
# Out:
# array(['House', 'Apartment', 'Boat', 'Townhouse', 'Condominium', 'Dorm',
#        'Earth House', 'Other', 'Bed & Breakfast', 'Loft', 'Guesthouse',
#        'Guest suite', 'Bungalow', 'Timeshare', 'Hostel', 'Chalet',
#        'Vacation home', 'In-law', 'Treehouse', 'Serviced apartment',
#        'Villa', 'Yurt', 'Cabin', 'Boutique hotel', 'Castle', 'Train'],
#       dtype=object)

# %%
collections.Counter(data['property_type'])
# Out:
# Counter({'House': 3159,
#          'Apartment': 24762,
#          'Boat': 9,
#          'Townhouse': 720,
#          'Condominium': 477,
#          'Dorm': 24,
#          'Earth House': 3,
#          'Other': 233,
#          'Bed & Breakfast': 110,
#          'Loft': 656,
#          'Guesthouse': 56,
#          'Guest suite': 52,
#          'Bungalow': 18,
#          'Timeshare': 74,
#          'Hostel': 38,
#          'Chalet': 3,
#          'Vacation home': 7,
#          'In-law': 6,
#          'Treehouse': 1,
#          'Serviced apartment': 7,
#          'Villa': 20,
#          'Yurt': 1,
#          'Cabin': 2,
#          'Boutique hotel': 20,
#          'Castle': 1,
#          'Train': 1})

# %%
data['property_type'] = data['property_type'].map({'House': 1, 'Apartment': 1, 'Townhouse': 1, 'Condominium': 1, 'Boat': 3,
                                                    'Dorm': 1, 'Earth House': 3, 'Other': 3, 'Bed & Breakfast':1,
                                                  'Loft':1, 'Guesthouse': 1, 'Guest suite': 1, 'Bungalow': 1,
                                                  'Timeshare': 2, 'Chalet':2, 'Vacation home': 2,'Hostel':3, 'In-law': 1,
                                                  'Treehouse': 3, 'Serviced apartment': 2, 'Villa': 2, 'Yurt': 3,
                                                  'Cabin': 2, 'Boutique hotel': 1, 'Castle': 3, 'Train': 3})

# %%
data.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
data['room_type'] = data['room_type'].map({'Private room': 2, 'Entire home/apt': 1, 'Shared room': 3})

# %%
data.bed_type.unique()
# Out:
# array(['Real Bed', 'Pull-out Sofa', 'Futon', 'Airbed', 'Couch'],
#       dtype=object)

# %%
collections.Counter(data['bed_type'])
# Out:
# Counter({'Real Bed': 29663,
#          'Pull-out Sofa': 262,
#          'Futon': 322,
#          'Airbed': 137,
#          'Couch': 76})

# %%
data['bed_type'] = data['bed_type'].map({'Real Bed': 1, 'Pull-out Sofa': 2, 'Futon': 2, 'Airbed': 2,
                                                  'Couch': 2})

# %%
data['instant_bookable'] = data['instant_bookable'].map({'f': 0, 't': 1})

# %%
data.cancellation_policy.unique()
# Out:
# array(['moderate', 'strict', 'flexible', 'super_strict_30',
#        'super_strict_60'], dtype=object)

# %%
collections.Counter(data['cancellation_policy'])
# Out:
# Counter({'moderate': 7779,
#          'strict': 15939,
#          'flexible': 6728,
#          'super_strict_30': 11,
#          'super_strict_60': 3})

# %%
data['cancellation_policy'] = data['cancellation_policy'].map({'moderate': 1, 'strict': 2, 'flexible': 3, 
                                                               'super_strict_30': 4, 'super_strict_60': 5})

# %%
def wifi(value):
    if "wireless internet" in value.lower():
        return 1
    else:
        return 0
    
data["wifi"] = data["amenities"].apply(wifi)

# %%
def tv(value):
    if "tv" in value.lower():
        return 1
    elif "cable tv" in value.lower():
        return 1
    else:
        return 0
    
data["tv"] = data["amenities"].apply(tv)

# %%
def ac(value):
    if "air conditioning" in value.lower():
        return 1
    else:
        return 0
    
data["ac"] = data["amenities"].apply(ac)

# %%
def kitchen(value):
    if "kitchen" in value.lower():
        return 1
    else:
        return 0
    
data["kitchen"] = data["amenities"].apply(kitchen)

# %%
def hair_dryer(value):
    if "hair dryer" in value.lower():
        return 1
    else:
        return 0
    
data["hair_dryer"] = data["amenities"].apply(hair_dryer)

# %%
def free_park(value):
    if "free parking on premises" in value.lower():
        return 1
    else:
        return 0
    
data["free_park"] = data["amenities"].apply(free_park)

# %%
data = data.drop(['amenities'], axis = 1)

# %%
data.to_csv("output2.csv")

# %%
data = pd.read_csv('output2.csv')

# %%
features_to_normalize = ['availability_30', 'number_of_reviews']
data[features_to_normalize] = data[features_to_normalize].apply(lambda x:10*((x-x.min()) / (x.max()-x.min())))

# %%
X1 = data.iloc[:,1:12] #independent columns
X2 = data.iloc[:,13:]
X = pd.concat([X1, X2], axis=1)
Y = data.iloc[:,12]    #target column i.e price range

# %% [markdown]
# # Starting Regression

# %%
model = LinearRegression()
model.fit(X,Y)
print(model.coef_) #use inbuilt class feature_importances of tree based classifiers
# Out:
# [  0.54318654 -47.78887609  14.87670157  -4.66551816  23.43709396
#  -72.16412633  28.33003625  86.37866273  19.88419287 -16.78798787
#    8.51156948   0.32454796   6.27887851  -9.33030461  -4.59952675
#    6.48209609 -11.25410344  15.26614249  10.52090189  -6.1143184
#   -0.32034783 -32.32370174]

# %%
y_pred2 = model.predict(X)

# %%
print(r2_score(Y,y_pred2))
# Out:
# 0.24294482330715184

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.coef_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# Most important features from Covariance matrix:
# room_type, accommodates, bathrooms, bedrooms, beds, tv

# %%
X1 = data[['room_type','accommodates','bathrooms','bedrooms','beds','tv']]
Y1 = data['price']

# %%
model1 = LinearRegression()
model1.fit(X1,Y1)
print(model1.coef_)
# Out:
# [-65.47897627  28.60377346  87.92050506  19.79567299 -17.30514088
#   16.34894945]

# %%
y_pred3 = model1.predict(X1)

# %%
print(r2_score(Y,y_pred3))
# Out:
# 0.22470418912781598

# %% [markdown]
# # PCA using one HOT encoding

# %%
pca = PCA(n_components = 10)

# %%
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
print('Components:\n ', pca.components_)
print('Explained Variance Ratio:\n ', pca.explained_variance_ratio_)
# Out:
# Components:
#   [[ 8.31647218e-03 -3.82248050e-04 -7.09935987e-04  1.15597154e-03
#   -2.98000509e-04 -2.35193484e-03 -1.13603142e-02  4.93891683e-04
#   -1.12112624e-03 -2.82986532e-03 -1.13028035e-04  9.99746438e-01
#   -1.45685842e-02 -7.96575316e-03 -3.04531683e-03 -7.96754136e-04
#    2.51042190e-04 -1.38355416e-04 -2.90446270e-04  1.12685770e-03
#   -2.04002802e-03 -7.12183169e-04]
#  [ 1.96918163e-02 -8.76995382e-03 -5.74058448e-03 -8.51487071e-03
#    2.60627202e-03  3.16250973e-02  2.19040687e-02  8.74294452e-03
#    1.29712177e-02  1.54126639e-02  2.21180935e-03  1.46101394e-02
#    9.98154569e-01 -1.86995402e-02 -4.51259463e-03  1.35814426e-02
#   -4.07736740e-03  8.93601746e-04 -7.25695833e-03 -9.23970696e-03
#   -8.84815243e-03  1.19063445e-02]
#  [-3.20627339e-02  4.91435422e-03  5.68113233e-03  5.16658293e-03
#    1.20936338e-03 -1.11844660e-01  8.45263900e-01  7.81749162e-02
#    2.38524807e-01  4.51198009e-01 -5.15949383e-03  1.10758144e-02
#   -2.39611491e-02  2.81355307e-02  8.64249120e-03 -1.60497025e-02
#    2.97922029e-03  4.17706522e-02  2.03421660e-02  1.08544073e-02
#    3.33218422e-02  8.89447153e-03]
#  [-8.71789862e-01  1.03540124e-01  8.49699602e-02  5.75915500e-03
#    6.40791998e-03  6.59168013e-02 -2.62562131e-02 -1.78217017e-02
#   -4.81973326e-02 -1.00113171e-02  2.91620231e-03  1.12852554e-02
#    2.86059278e-02  3.86369965e-01  1.72736884e-01 -1.48059343e-01
#    9.33220388e-03 -3.96368090e-03  2.51716928e-02 -1.73799128e-02
#    1.02870761e-01  2.40029394e-02]
#  [-3.92208288e-01  3.59306443e-02 -1.06799795e-01 -4.97325166e-02
#    4.24567300e-03  1.14981421e-01 -8.57934388e-02  8.30553219e-02
#    1.42743639e-01  1.45514392e-01 -5.70166414e-03 -2.59323514e-03
#   -1.96779229e-02 -7.49155252e-01  1.33655439e-01  4.10697228e-01
#   -1.73027600e-02 -6.97223619e-02 -5.86513690e-02 -1.10429183e-02
#   -7.08794451e-02 -3.46930315e-03]
#  [ 1.15480087e-01 -2.06858338e-02  4.05276411e-02  1.04706443e-02
#   -1.52423586e-02  2.31724993e-01 -2.92613879e-01  1.36089084e-01
#    3.14605261e-01  4.23910352e-01  5.06755833e-03  1.73506284e-03
#   -1.44746535e-02  4.78010605e-01  2.54232070e-03  5.57185435e-01
#   -7.52251986e-03 -7.08890794e-02 -3.20938976e-02 -1.93295126e-02
#   -4.06927314e-02  2.00031918e-02]
#  [ 3.37924320e-02  7.91847223e-03  5.08770921e-03  8.91174120e-03
#   -6.12764855e-03  1.94002267e-01 -3.24143860e-01  1.45701388e-01
#    3.25684191e-01  4.55349896e-01  8.21809077e-03 -4.06300953e-03
#   -6.06985513e-03 -1.65664595e-01 -5.29096607e-02 -6.94709529e-01
#    4.07310808e-03 -8.75260912e-02 -2.30950633e-02  5.29609044e-04
#    1.90751651e-03  1.01324151e-02]
#  [-1.53705383e-02  4.87751452e-03  3.83514967e-02 -2.84616072e-02
#   -4.00016593e-03 -4.43711870e-01 -2.43050926e-01 -1.27231964e-01
#   -3.67458362e-01  4.95825034e-01 -1.95815073e-02 -2.18443217e-03
#    1.98796037e-02 -7.41246950e-02 -3.25830181e-02  7.52284162e-02
#    2.84716388e-02  4.38284313e-01  1.51849778e-01  4.76186648e-02
#    3.36208019e-01 -1.29866346e-02]
#  [ 1.69369893e-02 -1.44812412e-02 -1.08087613e-01  1.42647394e-02
#    2.72751799e-02  6.57184223e-02  4.25818976e-02 -1.36686171e-01
#   -6.19553899e-01  3.68250728e-01  1.32898926e-02  4.85752665e-04
#   -3.79925813e-03  4.39346830e-02  9.97531995e-02 -3.67029461e-02
#   -4.75281381e-02 -4.58154077e-01 -1.49121759e-01 -8.35709092e-02
#   -4.31914777e-01 -3.53129311e-02]
#  [ 1.35068904e-01 -1.99754049e-02  6.78765964e-02 -2.04734945e-02
#    2.73003385e-02  3.99644864e-01  9.92603317e-02  7.28006065e-02
#   -2.40904158e-01  1.19342542e-02  1.49858478e-02  2.17122522e-03
#   -9.27386776e-03 -6.40181382e-02  1.57517790e-01  2.97001842e-02
#    1.34477668e-02 -3.36579349e-01  1.47913350e-02 -1.73830071e-02
#    7.73312731e-01  2.07910060e-02]]
# Explained Variance Ratio:
#   [0.76195856 0.11923108 0.06735671 0.01059655 0.00705729 0.00562915
#  0.00543001 0.00334706 0.00295828 0.00260763]

# %%
#plot explained variance 
plt.bar(range(pca.explained_variance_ratio_.shape[0]), pca.explained_variance_ratio_, alpha = 0.5, 
        align = 'center', label = 'individual explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
#plt.ylim(0, 0.02)
plt.legend(loc = 'best')
plt.tight_layout()

# %%
pipe1 = Pipeline([
    ('pca', PCA(n_components = 10)),
    ('linear', LinearRegression())
])

# %%
pipe1.fit(X,Y)
y_pred1 = pipe1.predict(X)

# %%
print(r2_score(Y,y_pred1))
# Out:
# 0.20453590170254343

# %%
K = pca.components_[0]
index = K.argsort()[-6:]

# %%
X.keys()[index]
# Out:
# Index(['wifi', 'bathrooms', 'kitchen', 'is_location_exact',
#        'host_response_time', 'minimum_nights'],
#       dtype='object')
